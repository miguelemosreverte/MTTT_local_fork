# %%
#Code to generate the evaluation output seen here

import libsemeval2014task5
import matplotlib.pyplot as plt
import glob
import os
import numpy as np
from IPython.display import HTML

DIR = "/home/migue/Desktop/semeval2014task5-master/evaluation/"
os.chdir(DIR)

def evaluate():

    for f in sorted(glob.glob('*xml')):
        if f.find('matrex') != -1:
            #skip intermediate files
            continue
        fields = os.path.basename(f).split('.')
        team = fields[0]
        L1, L2 = fields[1].split('-')
        run = fields[2]

        #Find evaluation type, can be best or oof
        #If not specified, the file will be evaluated according to both metrics
        if fields[3] == 'xml':
            eval = 'both'
        else:
            eval = fields[3]

        if eval == 'both' or eval == 'best':
            #BEST Evaluation
            print("Processing " + f  + " (BEST)")
            if eval == 'both':
                evalf = team + '.' + L1 + '-' + L2 + '.' + run + '.best.xml'
                os.rename(f, evalf) #temporary rename so output files will be consistently named
            else:
                evalf = f
            cmd = "semeval2014task5-evaluate -I --ref ../corpus/" + \
            L1 + "-" + L2 + ".gold.tokenised.xml --out " + evalf + "> " + evalf.replace('.xml','.log') + " 2> /dev/null"
            r = os.system(cmd)
            if eval == 'both':
                os.rename(evalf, f) #undo temporary rename
            if r != 0:
                print("Failed prematurely!")
                return
        if eval == 'both' or eval == 'oof':
            #OOF Evaluation
            print("Processing " + f  + " (OOF)")
            if eval == 'both':
                evalf = team + '.' + L1 + '-' + L2 + '.' + run + '.oof.xml'
                os.rename(f, evalf)  #temporary rename so output files will be consistently named
            else:
                evalf = f
            cmd = "semeval2014task5-evaluate -I -a --ref ../corpus/" + \
            L1 + "-" + L2 + ".gold.tokenised.xml --out " + evalf + "> " + evalf.replace('.xml','.log') + " 2> /dev/null"
            r = os.system(cmd)
            if eval == 'both':
                os.rename(evalf, f) #undo temporary rename
            if r != 0:
                print("Failed prematurely!")
                return
    print("Done")


evaluate()

data = {}

# %matplotlib inline
# Out:
# Processing CNRC.en-de.run1.xml (BEST)
# Processing CNRC.en-de.run1.xml (OOF)
# Processing CNRC.en-de.run2.xml (BEST)
# Processing CNRC.en-de.run2.xml (OOF)
# Processing CNRC.en-es.run1.xml (BEST)
# Processing CNRC.en-es.run1.xml (OOF)
# Processing CNRC.en-es.run2.xml (BEST)
# Processing CNRC.en-es.run2.xml (OOF)
# Processing CNRC.fr-en.run1.xml (BEST)
# Processing CNRC.fr-en.run1.xml (OOF)
# Processing CNRC.fr-en.run2.xml (BEST)
# Processing CNRC.fr-en.run2.xml (OOF)
# Processing CNRC.nl-en.run1.xml (BEST)
# Processing CNRC.nl-en.run1.xml (OOF)
# Processing CNRC.nl-en.run2.xml (BEST)
# Processing CNRC.nl-en.run2.xml (OOF)
# Processing IUCL.en-de.run1.best.xml (BEST)
# Processing IUCL.en-de.run1.oof.xml (OOF)
# Processing IUCL.en-de.run2.best.xml (BEST)
# Processing IUCL.en-de.run2.oof.xml (OOF)
# Processing IUCL.en-es.run1.best.xml (BEST)
# Processing IUCL.en-es.run1.oof.xml (OOF)
# Processing IUCL.en-es.run2.best.xml (BEST)
# Processing IUCL.en-es.run2.oof.xml (OOF)
# Processing IUCL.fr-en.run1.best.xml (BEST)
# Processing IUCL.fr-en.run1.oof.xml (OOF)
# Processing IUCL.fr-en.run2.best.xml (BEST)
# Processing IUCL.fr-en.run2.oof.xml (OOF)
# Processing IUCL.nl-en.run1.best.xml (BEST)
# Processing IUCL.nl-en.run1.oof.xml (OOF)
# Processing IUCL.nl-en.run2.best.xml (BEST)
# Processing IUCL.nl-en.run2.oof.xml (OOF)
# Processing Sensible.en-de.wtm.best.xml (BEST)
# Processing Sensible.en-de.wtm.oof.xml (OOF)
# Processing Sensible.en-de.wtmxling.best.xml (BEST)
# Processing Sensible.en-de.wtmxling.oof.xml (OOF)
# Processing Sensible.en-de.wtmxlingyu.best.xml (BEST)
# Processing Sensible.en-de.wtmxlingyu.oof.xml (OOF)
# Processing Sensible.en-es.wtm.best.xml (BEST)
# Processing Sensible.en-es.wtm.oof.xml (OOF)
# Processing Sensible.en-es.wtmxling.best.xml (BEST)
# Processing Sensible.en-es.wtmxling.oof.xml (OOF)
# Processing Sensible.en-es.wtmxlingyu.best.xml (BEST)
# Processing Sensible.en-es.wtmxlingyu.oof.xml (OOF)
# Processing Sensible.fr-en.wtm.best.xml (BEST)
# Processing Sensible.fr-en.wtm.oof.xml (OOF)
# Processing Sensible.fr-en.wtmxling.best.xml (BEST)
# Processing Sensible.fr-en.wtmxling.oof.xml (OOF)
# Processing Sensible.fr-en.wtmxlingyu.best.xml (BEST)
# Processing Sensible.fr-en.wtmxlingyu.oof.xml (OOF)
# Processing Sensible.nl-en.wtm.best.xml (BEST)
# Processing Sensible.nl-en.wtm.oof.xml (OOF)
# Processing Sensible.nl-en.wtmxling.best.xml (BEST)
# Processing Sensible.nl-en.wtmxling.oof.xml (OOF)
# Processing Sensible.nl-en.wtmxlingyu.best.xml (BEST)
# Processing Sensible.nl-en.wtmxlingyu.oof.xml (OOF)
# Processing TeamZ.en-de.run1.xml (BEST)
# Processing TeamZ.en-de.run1.xml (OOF)
# Processing TeamZ.en-es.run1.xml (BEST)
# Processing TeamZ.en-es.run1.xml (OOF)
# Processing UEdin.en-es.run1.best.xml (BEST)
# Processing UEdin.en-es.run1.oof.xml (OOF)
# Processing UEdin.en-es.run2.best.xml (BEST)
# Processing UEdin.en-es.run2.oof.xml (OOF)
# Processing UEdin.en-es.run3.best.xml (BEST)
# Processing UEdin.en-es.run3.oof.xml (OOF)
# Processing UEdin.fr-en.run1.best.xml (BEST)
# Processing UEdin.fr-en.run1.oof.xml (OOF)
# Processing UEdin.fr-en.run2.best.xml (BEST)
# Processing UEdin.fr-en.run2.oof.xml (OOF)
# Processing UEdin.fr-en.run3.best.xml (BEST)
# Processing UEdin.fr-en.run3.oof.xml (OOF)
# Processing UEdin.nl-en.run1.best.xml (BEST)
# Processing UEdin.nl-en.run1.oof.xml (OOF)
# Processing UEdin.nl-en.run2.best.xml (BEST)
# Processing UEdin.nl-en.run2.oof.xml (OOF)
# Processing UEdin.nl-en.run3.best.xml (BEST)
# Processing UEdin.nl-en.run3.oof.xml (OOF)
# Processing UNAL.en-es.run1.best.xml (BEST)
# Processing UNAL.en-es.run1.oof.xml (OOF)
# Processing UNAL.en-es.run2.best.xml (BEST)
# Done
